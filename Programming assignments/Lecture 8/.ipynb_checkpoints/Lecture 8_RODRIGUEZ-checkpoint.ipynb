# %% [markdown]
# # Decision Tree Programming Assignment
#
# ### by Joshua Rodriguez

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats
from scipy.io import arff
import warnings
warnings.filterwarnings("ignore", category=UserWarning)
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay,classification_report
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.tree import DecisionTreeRegressor
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.metrics import accuracy_score

# %% [markdown]
# # EDA

# %%
df = pd.read_excel('Real estate valuation data set.xlsx')
df.head()
# Out:
#    No  X1 transaction date  X2 house age  \
# 0   1          2012.916667          32.0
# 1   2          2012.916667          19.5
# 2   3          2013.583333          13.3
# 3   4          2013.500000          13.3
# 4   5          2012.833333           5.0
#
#    X3 distance to the nearest MRT station  X4 number of convenience stores  \
# 0                                84.87882                               10
# 1                               306.59470                                9
# 2                               561.98450                                5
# 3                               561.98450                                5
# 4                               390.56840                                5
#
#    X5 latitude  X6 longitude  Y house price of unit area
# 0     24.98298     121.54024                        37.9
# 1     24.98034     121.53951                        42.2
# 2     24.98746     121.54391                        47.3
# 3     24.98746     121.54391                        54.8
# 4     24.97937     121.54245                        43.1

# %%
df.dtypes
# Out:
# No                                           int64
# X1 transaction date                        float64
# X2 house age                               float64
# X3 distance to the nearest MRT station     float64
# X4 number of convenience stores              int64
# X5 latitude                                float64
# X6 longitude                               float64
# Y house price of unit area                 float64
# X2 house age_group                        category
# dtype: object

# %% [markdown]
# # Missing Values

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 414 entries, 0 to 413
# Data columns (total 8 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   No                                      414 non-null    int64
#  1   X1 transaction date                     414 non-null    float64
#  2   X2 house age                            414 non-null    float64
#  3   X3 distance to the nearest MRT station  414 non-null    float64
#  4   X4 number of convenience stores         414 non-null    int64
#  5   X5 latitude                             414 non-null    float64
#  6   X6 longitude                            414 non-null    float64
#  7   Y house price of unit area              414 non-null    float64
# dtypes: float64(6), int64(2)
# memory usage: 26.0 KB

# %%
df.isna().sum()
# Out:
# No                                        0
# X1 transaction date                       0
# X2 house age                              0
# X3 distance to the nearest MRT station    0
# X4 number of convenience stores           0
# X5 latitude                               0
# X6 longitude                              0
# Y house price of unit area                0
# dtype: int64

# %%
df['X2 house age_group'] = pd.cut(df['X2 house age'], bins=17)
sns.scatterplot(x='X2 house age', y='Y house price of unit area', data=df, hue='X2 house age_group', palette='Dark2')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()

# %%
sns.pairplot(df,hue='X2 house age',palette='Dark2')

# %% [markdown]
# # Train | Test Split

# %%
df.drop('X2 house age_group', axis=1, inplace=True)
df = df.astype(float)

# %%
df['Y_binned'] = pd.cut(df['Y house price of unit area'], bins=3, labels=['low', 'medium', 'high'])
X = df.drop(columns=['No', 'Y house price of unit area', 'Y_binned'])
y = df['Y_binned']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)
# Out:
# Shape of X_train: (289, 6)
# Shape of X_test: (125, 6)
# Shape of y_train: (289,)
# Shape of y_test: (125,)

# %% [markdown]
# # Decision Tree Classifier

# %% [markdown]
# ### Default Hyperparameters

# %%
model = DecisionTreeClassifier()
model.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred = model.predict(X_test)
labels = model.classes_

# %% [markdown]
# # Evaluation

# %%
cm = confusion_matrix(y_test, y_pred, labels=labels)
cmd = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=labels)

cmd.plot()
plt.show()

# %%
print(classification_report(y_test,base_pred))
# Out:
#               precision    recall  f1-score   support
#
#          low       0.90      0.89      0.89        88
#       medium       0.74      0.76      0.75        37
#
#     accuracy                           0.85       125
#    macro avg       0.82      0.82      0.82       125
# weighted avg       0.85      0.85      0.85       125

# %%
model.feature_importances_
# Out:
# array([0.10217161, 0.18824957, 0.41757957, 0.0308309 , 0.11435579,
#        0.14681256])

# %%
feature_names = X.columns
feature_importances = model.feature_importances_
pd.DataFrame(data=feature_importances, index=feature_names, columns=['Feature Importance'])
# Out:
#                                         Feature Importance
# X1 transaction date                               0.102172
# X2 house age                                      0.188250
# X3 distance to the nearest MRT station            0.417580
# X4 number of convenience stores                   0.030831
# X5 latitude                                       0.114356
# X6 longitude                                      0.146813

# %% [markdown]
# # Visualize the Tree

# %%
plt.figure(figsize=(12,8))
plot_tree(model)
# Out:
# [Text(0.5298295454545454, 0.9545454545454546, 'x[2] <= 390.769\ngini = 0.428\nsamples = 289\nvalue = [1, 200, 88]'),
#  Text(0.3153409090909091, 0.8636363636363636, 'x[1] <= 11.5\ngini = 0.484\nsamples = 122\nvalue = [1, 47, 74]'),
#  Text(0.20454545454545456, 0.7727272727272727, 'x[5] <= 121.541\ngini = 0.309\nsamples = 59\nvalue = [1, 10, 48]'),
#  Text(0.1590909090909091, 0.6818181818181818, 'x[3] <= 7.5\ngini = 0.473\nsamples = 29\nvalue = [1, 9, 19]'),
#  Text(0.13636363636363635, 0.5909090909090909, 'x[0] <= 2013.375\ngini = 0.54\nsamples = 21\nvalue = [1, 9, 11]'),
#  Text(0.11363636363636363, 0.5, 'x[0] <= 2013.042\ngini = 0.547\nsamples = 17\nvalue = [1, 9, 7]'),
#  Text(0.06818181818181818, 0.4090909090909091, 'x[0] <= 2012.792\ngini = 0.42\nsamples = 10\nvalue = [0, 3, 7]'),
#  Text(0.045454545454545456, 0.3181818181818182, 'x[0] <= 2012.708\ngini = 0.5\nsamples = 6\nvalue = [0, 3, 3]'),
#  Text(0.022727272727272728, 0.22727272727272727, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(0.06818181818181818, 0.22727272727272727, 'x[4] <= 24.969\ngini = 0.48\nsamples = 5\nvalue = [0, 2, 3]'),
#  Text(0.045454545454545456, 0.13636363636363635, 'x[3] <= 5.5\ngini = 0.5\nsamples = 4\nvalue = [0, 2, 2]'),
#  Text(0.022727272727272728, 0.045454545454545456, 'gini = 0.5\nsamples = 2\nvalue = [0, 1, 1]'),
#  Text(0.06818181818181818, 0.045454545454545456, 'gini = 0.5\nsamples = 2\nvalue = [0, 1, 1]'),
#  Text(0.09090909090909091, 0.13636363636363635, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(0.09090909090909091, 0.3181818181818182, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 4]'),
#  Text(0.1590909090909091, 0.4090909090909091, 'x[5] <= 121.531\ngini = 0.245\nsamples = 7\nvalue = [1, 6, 0]'),
#  Text(0.13636363636363635, 0.3181818181818182, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0]'),
#  Text(0.18181818181818182, 0.3181818181818182, 'gini = 0.0\nsamples = 6\nvalue = [0, 6, 0]'),
#  Text(0.1590909090909091, 0.5, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 4]'),
#  Text(0.18181818181818182, 0.5909090909090909, 'gini = 0.0\nsamples = 8\nvalue = [0, 0, 8]'),
#  Text(0.25, 0.6818181818181818, 'x[2] <= 387.215\ngini = 0.064\nsamples = 30\nvalue = [0, 1, 29]'),
#  Text(0.22727272727272727, 0.5909090909090909, 'gini = 0.0\nsamples = 27\nvalue = [0, 0, 27]'),
#  Text(0.2727272727272727, 0.5909090909090909, 'x[1] <= 5.1\ngini = 0.444\nsamples = 3\nvalue = [0, 1, 2]'),
#  Text(0.25, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(0.29545454545454547, 0.5, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2]'),
#  Text(0.42613636363636365, 0.7727272727272727, 'x[2] <= 142.167\ngini = 0.485\nsamples = 63\nvalue = [0, 37, 26]'),
#  Text(0.4034090909090909, 0.6818181818181818, 'gini = 0.0\nsamples = 7\nvalue = [0, 0, 7]'),
#  Text(0.44886363636363635, 0.6818181818181818, 'x[4] <= 24.977\ngini = 0.448\nsamples = 56\nvalue = [0, 37, 19]'),
#  Text(0.36363636363636365, 0.5909090909090909, 'x[1] <= 35.15\ngini = 0.238\nsamples = 29\nvalue = [0, 25, 4]'),
#  Text(0.3409090909090909, 0.5, 'x[5] <= 121.53\ngini = 0.137\nsamples = 27\nvalue = [0, 25, 2]'),
#  Text(0.3181818181818182, 0.4090909090909091, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(0.36363636363636365, 0.4090909090909091, 'x[5] <= 121.545\ngini = 0.074\nsamples = 26\nvalue = [0, 25, 1]'),
#  Text(0.3409090909090909, 0.3181818181818182, 'gini = 0.0\nsamples = 25\nvalue = [0, 25, 0]'),
#  Text(0.38636363636363635, 0.3181818181818182, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(0.38636363636363635, 0.5, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2]'),
#  Text(0.5340909090909091, 0.5909090909090909, 'x[5] <= 121.542\ngini = 0.494\nsamples = 27\nvalue = [0, 12, 15]'),
#  Text(0.4772727272727273, 0.5, 'x[2] <= 210.502\ngini = 0.298\nsamples = 11\nvalue = [0, 9, 2]'),
#  Text(0.45454545454545453, 0.4090909090909091, 'x[3] <= 8.5\ngini = 0.444\nsamples = 3\nvalue = [0, 1, 2]'),
#  Text(0.4318181818181818, 0.3181818181818182, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2]'),
#  Text(0.4772727272727273, 0.3181818181818182, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(0.5, 0.4090909090909091, 'gini = 0.0\nsamples = 8\nvalue = [0, 8, 0]'),
#  Text(0.5909090909090909, 0.5, 'x[2] <= 357.755\ngini = 0.305\nsamples = 16\nvalue = [0, 3, 13]'),
#  Text(0.5681818181818182, 0.4090909090909091, 'x[0] <= 2012.833\ngini = 0.231\nsamples = 15\nvalue = [0, 2, 13]'),
#  Text(0.5227272727272727, 0.3181818181818182, 'x[4] <= 24.983\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 1]'),
#  Text(0.5, 0.22727272727272727, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(0.5454545454545454, 0.22727272727272727, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(0.6136363636363636, 0.3181818181818182, 'x[1] <= 16.5\ngini = 0.142\nsamples = 13\nvalue = [0, 1, 12]'),
#  Text(0.5909090909090909, 0.22727272727272727, 'x[1] <= 16.25\ngini = 0.278\nsamples = 6\nvalue = [0, 1, 5]'),
#  Text(0.5681818181818182, 0.13636363636363635, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3]'),
#  Text(0.6136363636363636, 0.13636363636363635, 'x[0] <= 2013.375\ngini = 0.444\nsamples = 3\nvalue = [0, 1, 2]'),
#  Text(0.5909090909090909, 0.045454545454545456, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(0.6363636363636364, 0.045454545454545456, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2]'),
#  Text(0.6363636363636364, 0.22727272727272727, 'gini = 0.0\nsamples = 7\nvalue = [0, 0, 7]'),
#  Text(0.6136363636363636, 0.4090909090909091, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(0.7443181818181818, 0.8636363636363636, 'x[4] <= 24.974\ngini = 0.154\nsamples = 167\nvalue = [0, 153, 14]'),
#  Text(0.6477272727272727, 0.7727272727272727, 'x[1] <= 3.15\ngini = 0.035\nsamples = 113\nvalue = [0, 111, 2]'),
#  Text(0.6022727272727273, 0.6818181818181818, 'x[4] <= 24.971\ngini = 0.32\nsamples = 5\nvalue = [0, 4, 1]'),
#  Text(0.5795454545454546, 0.5909090909090909, 'gini = 0.0\nsamples = 4\nvalue = [0, 4, 0]'),
#  Text(0.625, 0.5909090909090909, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(0.6931818181818182, 0.6818181818181818, 'x[2] <= 492.944\ngini = 0.018\nsamples = 108\nvalue = [0, 107, 1]'),
#  Text(0.6704545454545454, 0.5909090909090909, 'x[0] <= 2013.458\ngini = 0.111\nsamples = 17\nvalue = [0, 16, 1]'),
#  Text(0.6477272727272727, 0.5, 'gini = 0.0\nsamples = 14\nvalue = [0, 14, 0]'),
#  Text(0.6931818181818182, 0.5, 'x[5] <= 121.536\ngini = 0.444\nsamples = 3\nvalue = [0, 2, 1]'),
#  Text(0.6704545454545454, 0.4090909090909091, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(0.7159090909090909, 0.4090909090909091, 'gini = 0.5\nsamples = 2\nvalue = [0, 1, 1]'),
#  Text(0.7159090909090909, 0.5909090909090909, 'gini = 0.0\nsamples = 91\nvalue = [0, 91, 0]'),
#  Text(0.8409090909090909, 0.7727272727272727, 'x[1] <= 8.95\ngini = 0.346\nsamples = 54\nvalue = [0, 42, 12]'),
#  Text(0.7840909090909091, 0.6818181818181818, 'x[5] <= 121.549\ngini = 0.32\nsamples = 5\nvalue = [0, 1, 4]'),
#  Text(0.7613636363636364, 0.5909090909090909, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 4]'),
#  Text(0.8068181818181818, 0.5909090909090909, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(0.8977272727272727, 0.6818181818181818, 'x[0] <= 2013.542\ngini = 0.273\nsamples = 49\nvalue = [0, 41, 8]'),
#  Text(0.8522727272727273, 0.5909090909090909, 'x[4] <= 24.974\ngini = 0.227\nsamples = 46\nvalue = [0, 40, 6]'),
#  Text(0.8295454545454546, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(0.875, 0.5, 'x[5] <= 121.543\ngini = 0.198\nsamples = 45\nvalue = [0, 40, 5]'),
#  Text(0.7954545454545454, 0.4090909090909091, 'x[2] <= 3128.25\ngini = 0.142\nsamples = 39\nvalue = [0, 36, 3]'),
#  Text(0.75, 0.3181818181818182, 'x[1] <= 30.05\ngini = 0.102\nsamples = 37\nvalue = [0, 35, 2]'),
#  Text(0.7272727272727273, 0.22727272727272727, 'gini = 0.0\nsamples = 24\nvalue = [0, 24, 0]'),
#  Text(0.7727272727272727, 0.22727272727272727, 'x[1] <= 33.95\ngini = 0.26\nsamples = 13\nvalue = [0, 11, 2]'),
#  Text(0.75, 0.13636363636363635, 'x[5] <= 121.537\ngini = 0.444\nsamples = 3\nvalue = [0, 1, 2]'),
#  Text(0.7272727272727273, 0.045454545454545456, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2]'),
#  Text(0.7727272727272727, 0.045454545454545456, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(0.7954545454545454, 0.13636363636363635, 'gini = 0.0\nsamples = 10\nvalue = [0, 10, 0]'),
#  Text(0.8409090909090909, 0.3181818181818182, 'x[0] <= 2013.458\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 1]'),
#  Text(0.8181818181818182, 0.22727272727272727, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(0.8636363636363636, 0.22727272727272727, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(0.9545454545454546, 0.4090909090909091, 'x[2] <= 722.911\ngini = 0.444\nsamples = 6\nvalue = [0, 4, 2]'),
#  Text(0.9318181818181818, 0.3181818181818182, 'x[5] <= 121.544\ngini = 0.32\nsamples = 5\nvalue = [0, 4, 1]'),
#  Text(0.9090909090909091, 0.22727272727272727, 'x[1] <= 12.8\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 1]'),
#  Text(0.8863636363636364, 0.13636363636363635, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(0.9318181818181818, 0.13636363636363635, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(0.9545454545454546, 0.22727272727272727, 'gini = 0.0\nsamples = 3\nvalue = [0, 3, 0]'),
#  Text(0.9772727272727273, 0.3181818181818182, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(0.9431818181818182, 0.5909090909090909, 'x[4] <= 24.975\ngini = 0.444\nsamples = 3\nvalue = [0, 1, 2]'),
#  Text(0.9204545454545454, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(0.9659090909090909, 0.5, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2]')]

# %%
plt.figure(figsize=(12, 8), dpi=150)
plot_tree(model, filled=True, feature_names=X.columns.tolist())
plt.show()

# %% [markdown]
# # Reporting Model Results

# %%
def report_model(model):
    model_preds = model.predict(X_test)
    print(classification_report(y_test,model_preds))
    print('\n')
    plt.figure(figsize=(12,8),dpi=150)
    plot_tree(model,filled=True,feature_names=df.drop('label', axis=1).columns,);

# %%
pruned_tree = DecisionTreeClassifier(max_depth=2)
pruned_tree.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(max_depth=2)

# %%
report_model(pruned_tree)
# Out:
#               precision    recall  f1-score   support
#
#          low       0.82      1.00      0.90        88
#       medium       1.00      0.49      0.65        37
#
#     accuracy                           0.85       125
#    macro avg       0.91      0.74      0.78       125
# weighted avg       0.87      0.85      0.83       125
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[172], line 1
# ----> 1 report_model(pruned_tree)
#
# Cell In[169], line 6, in report_model(model)
#       4 print('\n')
#       5 plt.figure(figsize=(12,8),dpi=150)
# ----> 6 plot_tree(model,filled=True,feature_names=df.drop('label', axis=1).columns,)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:5258, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5110 def drop(
#    5111     self,
#    5112     labels: IndexLabel = None,
#    (...)
#    5119     errors: IgnoreRaise = "raise",
#    5120 ) -> DataFrame | None:
#    5121     """
#    5122     Drop specified labels from rows or columns.
#    5123
#    (...)
#    5256             weight  1.0     0.8
#    5257     """
# -> 5258     return super().drop(
#    5259         labels=labels,
#    5260         axis=axis,
#    5261         index=index,
#    5262         columns=columns,
#    5263         level=level,
#    5264         inplace=inplace,
#    5265         errors=errors,
#    5266     )
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\generic.py:4549, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4547 for axis, labels in axes.items():
#    4548     if labels is not None:
# -> 4549         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4551 if inplace:
#    4552     self._update_inplace(obj)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\generic.py:4591, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4589         new_axis = axis.drop(labels, level=level, errors=errors)
#    4590     else:
# -> 4591         new_axis = axis.drop(labels, errors=errors)
#    4592     indexer = axis.get_indexer(new_axis)
#    4594 # Case for non-unique axis
#    4595 else:
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:6699, in Index.drop(self, labels, errors)
#    6697 if mask.any():
#    6698     if errors != "ignore":
# -> 6699         raise KeyError(f"{list(labels[mask])} not found in axis")
#    6700     indexer = indexer[~mask]
#    6701 return self.delete(indexer)
#
# KeyError: "['label'] not found in axis"
